# %% [markdown]
# # Importing Libraries

# %%
import warnings 
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from sklearn.ensemble import StackingRegressor
import numpy as np 
from alpha_vantage.timeseries import TimeSeries
import pandas as pd 
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
from pandas.plotting import lag_plot
from datetime import datetime
import time
import os
from sklearn.ensemble import VotingRegressor
import pandas as pd
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.pipeline import make_pipeline
import numpy as np
from tensorflow.keras.layers import GRU, LSTM, Bidirectional, Dense, Flatten, Conv1D, BatchNormalization, LeakyReLU, Dropout, SimpleRNN, GRU, Bidirectional
from pickle import load
from pandas.plotting import lag_plot
from pandas import DataFrame
from pandas import concat
import mplfinance as mpf
import matplotlib.dates as mdates
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
# Out:
# WARNING:tensorflow:From C:\Users\ZUBAIR\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Importing Dataset

# %%
import yfinance

def get_historical(quote):
    end = datetime.now()
    start = datetime(end.year - 2, end.month, end.day)
    data = yfinance.download(quote, start=start, end=end)
    df = pd.DataFrame(data=data)
    df.to_csv("" + quote + ".csv")
    if df.empty:
        ts = TimeSeries(key="dj0yJmk9WVJxNlRuYlZ3TXVjJmQ9WVdrOU1HSTNaMDVFZUZrbWNHbzlNQT09JnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWQ1", output_format="pandas")
        data= ts.get_daily_adjusted(symbol="NSE:" + quote, outputsize="full")
        data = data.head(503).iloc[::-1]
        data = data.reset_index()
        df = pd.DataFrame()
        df["Date"] = data["date"]
        df["Open"] = data["1. open"]
        df["High"] = data["2. high"]
        df["Low"] = data["3. low"]
        df["Close"] = data["4. close"]
        df["Adj Close"] = data["5. adjusted close"]
        df["Volume"] = data["6. volume"]
        df.to_csv("" + quote + ".csv", index=False)
    return

# %%
nm = input()
get_historical(nm)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dateparse = lambda dates: pd.to_datetime(dates, format='%Y-%m-%d')
data = pd.read_csv('AMZN.csv', sep=',', parse_dates=['Date'], index_col='Date', date_parser=dateparse)
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(data['Open'])

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 502 entries, 2022-03-14 to 2024-03-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       502 non-null    float64
#  1   High       502 non-null    float64
#  2   Low        502 non-null    float64
#  3   Close      502 non-null    float64
#  4   Adj Close  502 non-null    float64
#  5   Volume     502 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 27.5 KB

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-03-14  145.981003  147.449997  140.884003  141.852997  141.852997
# 2022-03-15  142.850006  147.985001  142.000000  147.366501  147.366501
# 2022-03-16  148.500000  153.149994  147.353500  153.104004  153.104004
# 2022-03-17  152.640503  157.498505  152.139999  157.238998  157.238998
# 2022-03-18  156.813004  161.593994  156.011002  161.250504  161.250504
#
#                Volume
# Date
# 2022-03-14   74086000
# 2022-03-15   75584000
# 2022-03-16   84958000
# 2022-03-17   72934000
# 2022-03-18  102962000

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-06  175.539993  176.460007  173.259995  173.509995  173.509995
# 2024-03-07  174.830002  177.990005  173.720001  176.820007  176.820007
# 2024-03-08  176.440002  178.789993  174.330002  175.350006  175.350006
# 2024-03-11  174.309998  174.470001  171.470001  171.960007  171.960007
# 2024-03-12  173.500000  176.759995  171.979996  175.389999  175.389999
#
#               Volume
# Date
# 2024-03-06  32090900
# 2024-03-07  34063300
# 2024-03-08  37853500
# 2024-03-11  28484800
# 2024-03-12  36564800

# %%
data.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  502.000000  502.000000  502.000000  502.000000  502.000000
# mean   124.852381  126.633633  123.082579  124.919545  124.919545
# std     23.367233   23.392651   23.393606   23.436673   23.436673
# min     82.800003   83.480003   81.430000   81.820000   81.820000
# 25%    104.190002  106.134998  102.519997  104.470003  104.470003
# 50%    125.279999  127.365002  124.000000  125.854248  125.854248
# 75%    141.255005  143.377502  139.819996  142.023251  142.023251
# max    177.529999  180.139999  177.490005  178.220001  178.220001
#
#              Volume
# count  5.020000e+02
# mean   6.410433e+07
# std    2.723822e+07
# min    2.237840e+07
# 25%    4.737212e+07
# 50%    5.675740e+07
# 75%    7.226162e+07
# max    2.726620e+08

# %%
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # Data Visulization

# %%
plt.figure(figsize=(12,8))
lag_plot(data['Open'], lag=1)
plt.title('Autocorrelation plot')
plt.grid(True)
plt.legend()


values = DataFrame(data['Open'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000  0.127553
# t+1  0.127553  1.000000

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price Over Time')
plt.legend()
plt.show()

# %%
mpf.plot(data, type='candle', style='charles', title='Candlestick Chart', volume=True)

# %%
train_data, test_data = data[0:int(len(data)*0.9)], data[int(len(data)*0.9):]
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(data['Open'], 'green', label='Train data')
plt.plot(test_data['Open'], 'blue', label='Test data')
plt.legend()

# %%
sns.histplot(data['Volume'], kde=True)
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.title('Volume Distribution')
plt.show()

# %%
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
df = data
x = mdates.date2num(df.index)

width = 0.2  # Adjust the width as needed

plt.bar(x - width, df['Open'], width=width, label='Open')
plt.bar(x, df['High'], width=width, label='High')
plt.bar(x + width, df['Low'], width=width, label='Low')
plt.bar(x + 2 * width, df['Close'], width=width, label='Close')

plt.xlabel('Data Point')
plt.ylabel('Price')
plt.title('NIfty Prices')
plt.legend()
plt.show()

# %%
sns.boxplot(data=df[['Open', 'High', 'Low', 'Close']])
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %% [markdown]
# # Model Building

# %%
train = train_data.iloc[:, 0:1].values 
scaler = MinMaxScaler() 
train_scaled = scaler.fit_transform(train)
timesteps = 7
X_train = []
y_train = []
for i in range(timesteps, train.shape[0]):
    X_train.append(train_scaled[i-timesteps:i, 0]) 
    y_train.append(train_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
test = test_data.iloc[:, 0:1].values 
scaler = MinMaxScaler() 
test_scaled = scaler.fit_transform(test)
timesteps = 7
X_test = []
y_test = []
for i in range(timesteps, test.shape[0]):
    X_test.append(test_scaled[i-timesteps:i, 0]) 
    y_test.append(test_scaled[i, 0]) 
X_test, y_test = np.array(X_test), np.array(y_test)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # ANN

# %%
ann = MLPRegressor(random_state=1, max_iter=500)
ann.fit(X_train, y_train)
# Out:
# MLPRegressor(max_iter=500, random_state=1)

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = ann.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse8 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse8))
mae8 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae8))
rmse8 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse8))
r28 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r28))
# Out:
# MSE: 19.156567784991722
# MAE: 3.403578880648701
# RMSE: 4.376821653322388
# R2 Score: 0.8120119342914796

# %% [markdown]
# # Voting Classifier

# %%
regressor1 = RandomForestRegressor()
regressor2 = GradientBoostingRegressor()
regressor3 = LinearRegression()

# Create a voting regressor
voting_regressor = VotingRegressor(estimators=[('rf', regressor1), ('gb', regressor2), ('lr', regressor3)])

# Fit the ensemble model
voting_regressor.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('rf', RandomForestRegressor()),
#                             ('gb', GradientBoostingRegressor()),
#                             ('lr', LinearRegression())])

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = voting_regressor.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse9 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse9))
mae9 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae9))
rmse9 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse9))
r29 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r29))
# Out:
# MSE: 8.787352486700327
# MAE: 2.06624021552416
# RMSE: 2.9643468904128487
# R2 Score: 0.9137675696808302

# %% [markdown]
# # Stacking Classifier

# %%
regressor1 = RandomForestRegressor(random_state=42)
regressor2 = GradientBoostingRegressor(random_state=42)
regressor3 = LinearRegression()

# Create a stacking regressor
stacked_regressor = StackingRegressor(
    estimators=[('rf', regressor1), ('gb', regressor2), ('lr', regressor3)],
    final_estimator=LinearRegression()
)

# Fit the ensemble model
stacked_regressor.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor(random_state=42)),
#                               ('gb',
#                                GradientBoostingRegressor(random_state=42)),
#                               ('lr', LinearRegression())],
#                   final_estimator=LinearRegression())

# %%
real_stock_price = test_data.iloc[:, 0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis=0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1, 1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0] + timesteps):
    X_test.append(test_inputs[i - timesteps:i, 0])

X_test = np.array(X_test)


X_test = X_test.reshape(X_test.shape[0], timesteps)

predicted_stock_price = stacked_regressor.predict(X_test)


predicted_stock_price = predicted_stock_price.reshape(-1, 1)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16, 8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label='Train Stock Price')
plt.plot(test_data.index, real_stock_price, color='red', label='Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse10 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse10))
mae10 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae10))
rmse10 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse10))
r210 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r210))
# Out:
# MSE: 8.090157930551372
# MAE: 1.9871327784389916
# RMSE: 2.8443202932425478
# R2 Score: 0.9206093096785157

# %% [markdown]
# # Deep Learning

# %%
train = train_data.iloc[:, 0:1].values

# %%
scaler = MinMaxScaler() 
train_scaled = scaler.fit_transform(train)

# %%
timesteps = 7
X_train = []
y_train = []
for i in range(timesteps, train.shape[0]):
    X_train.append(train_scaled[i-timesteps:i, 0]) 
    y_train.append(train_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) #Reshaping
from numpy.random import seed 
seed(2019)

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.layers import LSTM,Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam


model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1), activation='relu'))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True, activation='relu'))
model.add(Dropout(0.25))

model.add(LSTM(units=50, return_sequences=True, activation='relu'))
model.add(Dropout(0.2))

model.add(LSTM(units=50, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(units=1))

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer = optimizer, loss = 'mean_squared_error')

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 7, 50)             10400
#
#  dropout_20 (Dropout)        (None, 7, 50)             0
#
#  lstm_13 (LSTM)              (None, 7, 50)             20200
#
#  dropout_21 (Dropout)        (None, 7, 50)             0
#
#  lstm_14 (LSTM)              (None, 7, 50)             20200
#
#  dropout_22 (Dropout)        (None, 7, 50)             0
#
#  lstm_15 (LSTM)              (None, 50)                20200
#
#  dropout_23 (Dropout)        (None, 50)                0
#
#  dense_6 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 71051 (277.54 KB)
# Trainable params: 71051 (277.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# model.fit(X_train, y_train, epochs = 40, batch_size = 32)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 9s 104ms/step - loss: 0.1493 - val_loss: 0.2068
# Epoch 2/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0579 - val_loss: 0.0247
# Epoch 3/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0357 - val_loss: 0.0494
# Epoch 4/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0247 - val_loss: 0.0128
# Epoch 5/50
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0153 - val_loss: 0.0053
# Epoch 6/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0151 - val_loss: 0.0134
# Epoch 7/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0136 - val_loss: 0.0270
# Epoch 8/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0125 - val_loss: 0.0075
# Epoch 9/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0102 - val_loss: 0.0031
# Epoch 10/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0128 - val_loss: 0.0162
# Epoch 11/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0101 - val_loss: 0.0040
# Epoch 12/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0113 - val_loss: 0.0072
# Epoch 13/50
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0117 - val_loss: 0.0037
# Epoch 14/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0110 - val_loss: 0.0090
# Epoch 15/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 16/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0090 - val_loss: 0.0047
# Epoch 17/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 18/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0085 - val_loss: 0.0029
# Epoch 19/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0091 - val_loss: 0.0071
# Epoch 20/50
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 21/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0097 - val_loss: 0.0032
# Epoch 22/50
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0108 - val_loss: 0.0048
# Epoch 23/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0083 - val_loss: 0.0138
# Epoch 24/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0085 - val_loss: 0.0046
# Epoch 25/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0084 - val_loss: 0.0053
# Epoch 26/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 27/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0088 - val_loss: 0.0027
# Epoch 28/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0076 - val_loss: 0.0035
# Epoch 29/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0078 - val_loss: 0.0086
# Epoch 30/50
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0090 - val_loss: 0.0072
# Epoch 31/50
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0083 - val_loss: 0.0059
# Epoch 32/50
# 12/12 [==============================] - 0s 41ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 33/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0077 - val_loss: 0.0025
# Epoch 34/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0078 - val_loss: 0.0024
# Epoch 35/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0082 - val_loss: 0.0026
# Epoch 36/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0076 - val_loss: 0.0050
# Epoch 37/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 38/50
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0070 - val_loss: 0.0107
# Epoch 39/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0074 - val_loss: 0.0098
# Epoch 40/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 41/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 42/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0067 - val_loss: 0.0024
# Epoch 43/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 44/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0070 - val_loss: 0.0028
# Epoch 45/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 46/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 47/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0077 - val_loss: 0.0100
# Epoch 48/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0066 - val_loss: 0.0053
# Epoch 49/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0066 - val_loss: 0.0023
# Epoch 50/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0066 - val_loss: 0.0031

# %%
real_stock_price = test_data.iloc[:,0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)

predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16,8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2/2 [==============================] - 1s 9ms/step

# %%
mse12 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse12))
mae12 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae12))
rmse12 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse12))
r212 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r212))
# Out:
# MSE: 52.47185515728779
# MAE: 6.384283028396905
# RMSE: 7.243745934065315
# R2 Score: 0.48508090458227926

# %% [markdown]
# ## GRU

# %%
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
model = Sequential()

model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1), activation='tanh'))
model.add(Dropout(0.2))

model.add(GRU(units=50, return_sequences=True, activation='tanh'))
model.add(Dropout(0.25))

model.add(GRU(units=50, return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))

model.add(GRU(units=50, activation='tanh'))
model.add(Dropout(0.25))

model.add(Dense(units=1, activation='linear'))

# %%
optimizer = Adam(learning_rate=0.001)
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_4 (GRU)                 (None, 7, 50)             7950
#
#  dropout_24 (Dropout)        (None, 7, 50)             0
#
#  gru_5 (GRU)                 (None, 7, 50)             15300
#
#  dropout_25 (Dropout)        (None, 7, 50)             0
#
#  gru_6 (GRU)                 (None, 7, 50)             15300
#
#  dropout_26 (Dropout)        (None, 7, 50)             0
#
#  gru_7 (GRU)                 (None, 50)                15300
#
#  dropout_27 (Dropout)        (None, 50)                0
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 53901 (210.55 KB)
# Trainable params: 53901 (210.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 12s 182ms/step - loss: 0.0757 - val_loss: 0.0079
# Epoch 2/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0207 - val_loss: 0.0095
# Epoch 3/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0112 - val_loss: 0.0106
# Epoch 4/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0092 - val_loss: 0.0025
# Epoch 5/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0080 - val_loss: 0.0031
# Epoch 6/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0077 - val_loss: 0.0026
# Epoch 7/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0086 - val_loss: 0.0074
# Epoch 8/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0080 - val_loss: 0.0037
# Epoch 9/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0071 - val_loss: 0.0024
# Epoch 10/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0089 - val_loss: 0.0026
# Epoch 11/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0075 - val_loss: 0.0055
# Epoch 12/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0071 - val_loss: 0.0024
# Epoch 13/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0078 - val_loss: 0.0025
# Epoch 14/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0071 - val_loss: 0.0046
# Epoch 15/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 16/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0065 - val_loss: 0.0042
# Epoch 17/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 18/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0079 - val_loss: 0.0086
# Epoch 19/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 20/50
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0068 - val_loss: 0.0036
# Epoch 21/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0062 - val_loss: 0.0046
# Epoch 22/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0056 - val_loss: 0.0029
# Epoch 23/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0077 - val_loss: 0.0021
# Epoch 24/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0067 - val_loss: 0.0020
# Epoch 25/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 26/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0062 - val_loss: 0.0021
# Epoch 27/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0060 - val_loss: 0.0023
# Epoch 28/50
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0057 - val_loss: 0.0018
# Epoch 29/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 30/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 31/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 32/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0067 - val_loss: 0.0025
# Epoch 33/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0061 - val_loss: 0.0020
# Epoch 34/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0069 - val_loss: 0.0023
# Epoch 35/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 36/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 37/50
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 38/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 39/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 40/50
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 41/50
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 42/50
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 43/50
# 12/12 [==============================] - 0s 39ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 44/50
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0082 - val_loss: 0.0014
# Epoch 45/50
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 46/50
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 47/50
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 48/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 49/50
# 12/12 [==============================] - 0s 42ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 50/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0044 - val_loss: 0.0013

# %%
real_stock_price = test_data.iloc[:,0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)

predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16,8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000024444C4B2E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 3s 7ms/step

# %%
mse13 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse13))
mae13 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae13))
rmse13 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse13))
r213 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r213))
# Out:
# MSE: 11.252264201613691
# MAE: 2.529888676662071
# RMSE: 3.354439476516709
# R2 Score: 0.8895787906349373

# %% [markdown]
# # BiLSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Bidirectional


model = Sequential()
model.add(Bidirectional(LSTM(units=50, return_sequences=True), input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.20))

model.add(Bidirectional(LSTM(units=50, return_sequences=True)))
model.add(Dropout(0.25))

model.add(Bidirectional(LSTM(units=50, return_sequences=True)))
model.add(Dropout(0.2))

model.add(Bidirectional(LSTM(units=50)))
model.add(Dropout(0.25))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirecti  (None, 7, 100)            20800
#  onal)
#
#  dropout_28 (Dropout)        (None, 7, 100)            0
#
#  bidirectional_5 (Bidirecti  (None, 7, 100)            60400
#  onal)
#
#  dropout_29 (Dropout)        (None, 7, 100)            0
#
#  bidirectional_6 (Bidirecti  (None, 7, 100)            60400
#  onal)
#
#  dropout_30 (Dropout)        (None, 7, 100)            0
#
#  bidirectional_7 (Bidirecti  (None, 100)               60400
#  onal)
#
#  dropout_31 (Dropout)        (None, 100)               0
#
#  dense_8 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 202101 (789.46 KB)
# Trainable params: 202101 (789.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 40, batch_size = 32)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 21s 25ms/step - loss: 0.0680
# Epoch 2/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0173
# Epoch 3/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0074
# Epoch 4/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0059
# Epoch 5/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0059
# Epoch 6/40
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0052
# Epoch 7/40
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0058
# Epoch 8/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0057
# Epoch 9/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0049
# Epoch 10/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0046
# Epoch 11/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0053
# Epoch 12/40
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0055
# Epoch 13/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0049
# Epoch 14/40
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0041
# Epoch 15/40
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0044
# Epoch 16/40
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0040
# Epoch 17/40
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0047
# Epoch 18/40
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0039
# Epoch 19/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0042
# Epoch 20/40
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 21/40
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0041
# Epoch 22/40
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0040
# Epoch 23/40
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0040
# Epoch 24/40
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0035
# Epoch 25/40
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0054
# Epoch 26/40
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0047
# Epoch 27/40
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0041
# Epoch 28/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0034
# Epoch 29/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033
# Epoch 30/40
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0035
# Epoch 31/40
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0032
# Epoch 32/40
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0037
# Epoch 33/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0036
# Epoch 34/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0044
# Epoch 35/40
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0034
# Epoch 36/40
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0032
# Epoch 37/40
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0032
# Epoch 38/40
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0033
# Epoch 39/40
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037
# Epoch 40/40
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0036

# %%
real_stock_price = test_data.iloc[:,0:1].values
combine = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)

predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

plt.figure(figsize=(16,8))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000024426EE2F20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 5s 8ms/step

# %%
mse14 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse14))
mae14 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae14))
rmse14 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse14))
r214 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r214))
# Out:
# MSE: 18.40257614621363
# MAE: 3.461917951995251
# RMSE: 4.289822390987024
# R2 Score: 0.8194110378952753

# %% [markdown]
# # CNN

# %%
# the CNN model
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()

model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.1))

model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dropout(0.4))

model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(units=1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 7, 64)             256
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 64)             0
#  g1D)
#
#  dropout_32 (Dropout)        (None, 3, 64)             0
#
#  batch_normalization_1 (Bat  (None, 3, 64)             256
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 3, 128)            24704
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 128)            0
#  g1D)
#
#  dropout_33 (Dropout)        (None, 1, 128)            0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dropout_34 (Dropout)        (None, 128)               0
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dropout_35 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 41857 (163.50 KB)
# Trainable params: 41729 (163.00 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['acc'])
model.fit(X_train, y_train, epochs = 40, batch_size = 32)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 3s 7ms/step - loss: 0.0301 - acc: 0.0045
# Epoch 2/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0140 - acc: 0.0045
# Epoch 3/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0112 - acc: 0.0045
# Epoch 4/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0106 - acc: 0.0045
# Epoch 5/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0097 - acc: 0.0045
# Epoch 6/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0090 - acc: 0.0045
# Epoch 7/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0083 - acc: 0.0045
# Epoch 8/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0086 - acc: 0.0045
# Epoch 9/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0087 - acc: 0.0045
# Epoch 10/40
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0071 - acc: 0.0045
# Epoch 11/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0060 - acc: 0.0045
# Epoch 12/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0058 - acc: 0.0045
# Epoch 13/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0054 - acc: 0.0045
# Epoch 14/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0051 - acc: 0.0045
# Epoch 15/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0050 - acc: 0.0045
# Epoch 16/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0050 - acc: 0.0045
# Epoch 17/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0045 - acc: 0.0045
# Epoch 18/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0059 - acc: 0.0045
# Epoch 19/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0050 - acc: 0.0045
# Epoch 20/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0045 - acc: 0.0045
# Epoch 21/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - acc: 0.0045
# Epoch 22/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - acc: 0.0045
# Epoch 23/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - acc: 0.0045
# Epoch 24/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - acc: 0.0045
# Epoch 25/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - acc: 0.0045
# Epoch 26/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0050 - acc: 0.0045
# Epoch 27/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0042 - acc: 0.0045
# Epoch 28/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - acc: 0.0045
# Epoch 29/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0039 - acc: 0.0045
# Epoch 30/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0045 - acc: 0.0045
# Epoch 31/40
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0038 - acc: 0.0045
# Epoch 32/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0044 - acc: 0.0045
# Epoch 33/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0035 - acc: 0.0045
# Epoch 34/40
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0051 - acc: 0.0045
# Epoch 35/40
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0035 - acc: 0.0045
# Epoch 36/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0050 - acc: 0.0045
# Epoch 37/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0040 - acc: 0.0045
# Epoch 38/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0043 - acc: 0.0045
# Epoch 39/40
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0033 - acc: 0.0045
# Epoch 40/40
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - acc: 0.0045

# %%
real_stock_price_CNN = test_data.iloc[:,0:1].values
combine_CNN = pd.concat((train_data['Open'], test_data['Open']), axis = 0)

test_inputs_CNN = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs_CNN = test_inputs_CNN.reshape(-1,1)
test_inputs_CNN = scaler.transform(test_inputs_CNN)
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs_CNN[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
print("predicted stock price for tomorrow: ",predicted_stock_price[len(predicted_stock_price)-1])

plt.figure(figsize=(16,5))
plt.plot(data.index[-600:], data['Open'].tail(600), color='green', label = 'Train Stock Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step
# predicted stock price for tomorrow:  [146.8703]

# %%
mse15 = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse12))
mae15 = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae12))
rmse15 = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse12))
r215 = r2_score(real_stock_price, predicted_stock_price)
print('R2 Score: ' + str(r215))
# Out:
# MSE: 52.47185515728779
# MAE: 6.384283028396905
# RMSE: 7.243745934065315
# R2 Score: -4.754572817129855

# %% [markdown]
# # Comparison

# %%
results = {
    'R-squared': [r28, r29, r210,r212,r213,r214,r215],
    'Mean Squared Error': [ mse8, mse9, mse10, mse12, mse13, mse14, mse15],
    'Mean Absolute Error': [ mae8, mae9, mae10, mae12, mae13, mae14, mae15],
    'Root Mean Squared Error': [rmse8, rmse9, rmse10, rmse12, rmse13, rmse14, rmse15]
}


index = ['ANN','Voting Classifier','Stacking Classifier','LSTM','GRU','BiLSTM','CNN']

# %%
results =pd.DataFrame(results,index=index)

# %%
print(results)
# Out:
#                      R-squared  Mean Squared Error  Mean Absolute Error  \
# ANN                   0.812012           19.156568             3.403579
# Voting Classifier     0.913768            8.787352             2.066240
# Stacking Classifier   0.920609            8.090158             1.987133
# LSTM                  0.485081           52.471855             6.384283
# GRU                   0.889579           11.252264             2.529889
# BiLSTM                0.819411           18.402576             3.461918
# CNN                  -4.754573          586.408844            23.698885
#
#                      Root Mean Squared Error
# ANN                                 4.376822
# Voting Classifier                   2.964347
# Stacking Classifier                 2.844320
# LSTM                                7.243746
# GRU                                 3.354439
# BiLSTM                              4.289822
# CNN                                24.215880

# %%
fig =results.plot(kind='bar',title='Comaprison of models',figsize =(8,8)).get_figure()
fig.savefig('Final Result.png')

# %%
def visualize_metric(metric, color):
    plt.figure(figsize=(10, 6))
    plt.bar(index, results[metric], color=color)
    plt.xlabel('Models')
    plt.ylabel(metric)
    plt.title(f'{metric} for Different Models')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


visualize_metric('R-squared', 'green')

# %%
def visualize_metric(metric, color):
    plt.figure(figsize=(10, 6))
    plt.bar(index, results[metric], color=color)
    plt.xlabel('Models')
    plt.ylabel(metric)
    plt.title(f'{metric} for Different Models')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()


visualize_metric('Mean Squared Error', 'orange')

# %%
visualize_metric('Mean Absolute Error', 'purple')

# %%
visualize_metric('Root Mean Squared Error', 'pink')
